# %% [markdown]
# Installing Dependancies

# %%
# !pip install efficient_apriori

# %%
from efficient_apriori import apriori
import pandas as pd

# %% [markdown]
# Reading CSV Data File

# %%
df = pd.read_csv('groceries.csv')

# %%
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
df.describe()
# Out:
#        Member_number
# count   38765.000000
# mean     3003.641868
# std      1153.611031
# min      1000.000000
# 25%      2002.000000
# 50%      3005.000000
# 75%      4007.000000
# max      5000.000000

# %%
df["itemDescription"].value_counts()
# Out:
# itemDescription
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
#                          ...
# rubbing alcohol             5
# bags                        4
# baby cosmetics              3
# kitchen utensil             1
# preservation products       1
# Name: count, Length: 167, dtype: int64

# %% [markdown]
# checking null values and settling them

# %%
df.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
df.shape
# Out:
# (38765, 3)

# %% [markdown]
# using apriori function with minimum support and minimum confidence

# %%
item_sets , rules = apriori(df, min_support=0.02, min_confidence=0.05)

# %%
item_sets
# Out:
# {1: {('M',): 1,
#   ('e',): 3,
#   ('m',): 2,
#   ('b',): 1,
#   ('r',): 2,
#   ('_',): 1,
#   ('n',): 2,
#   ('u',): 1,
#   ('D',): 2,
#   ('a',): 1,
#   ('t',): 2,
#   ('i',): 1,
#   ('s',): 1,
#   ('c',): 1,
#   ('p',): 1,
#   ('o',): 1},
#  2: {('D', 'a'): 1,
#   ('D', 'c'): 1,
#   ('D', 'e'): 2,
#   ('D', 'i'): 1,
#   ('D', 'm'): 1,
#   ('D', 'n'): 1,
#   ('D', 'o'): 1,
#   ('D', 'p'): 1,
#   ('D', 'r'): 1,
#   ('D', 's'): 1,
#   ('D', 't'): 2,
#   ('M', '_'): 1,
#   ('M', 'b'): 1,
#   ('M', 'e'): 1,
#   ('M', 'm'): 1,
#   ('M', 'n'): 1,
#   ('M', 'r'): 1,
#   ('M', 'u'): 1,
#   ('_', 'b'): 1,
#   ('_', 'e'): 1,
#   ('_', 'm'): 1,
#   ('_', 'n'): 1,
#   ('_', 'r'): 1,
#   ('_', 'u'): 1,
#   ('a', 'e'): 1,
#   ('a', 't'): 1,
#   ('b', 'e'): 1,
#   ('b', 'm'): 1,
#   ('b', 'n'): 1,
#   ('b', 'r'): 1,
#   ('b', 'u'): 1,
#   ('c', 'e'): 1,
#   ('c', 'i'): 1,
#   ('c', 'm'): 1,
#   ('c', 'n'): 1,
#   ('c', 'o'): 1,
#   ('c', 'p'): 1,
#   ('c', 'r'): 1,
#   ('c', 's'): 1,
# ...

# %%
rules
# Out:
# [{a} -> {D},
#  {D} -> {a},
#  {c} -> {D},
#  {D} -> {c},
#  {e} -> {D},
#  {D} -> {e},
#  {i} -> {D},
#  {D} -> {i},
#  {m} -> {D},
#  {D} -> {m},
#  {n} -> {D},
#  {D} -> {n},
#  {o} -> {D},
#  {D} -> {o},
#  {p} -> {D},
#  {D} -> {p},
#  {r} -> {D},
#  {D} -> {r},
#  {s} -> {D},
#  {D} -> {s},
#  {t} -> {D},
#  {D} -> {t},
#  {_} -> {M},
#  {M} -> {_},
#  {b} -> {M},
#  {M} -> {b},
#  {e} -> {M},
#  {M} -> {e},
#  {m} -> {M},
#  {M} -> {m},
#  {n} -> {M},
#  {M} -> {n},
#  {r} -> {M},
#  {M} -> {r},
#  {u} -> {M},
#  {M} -> {u},
#  {b} -> {_},
#  {_} -> {b},
#  {e} -> {_},
#  {_} -> {e},
#  {m} -> {_},
#  {_} -> {m},
#  {n} -> {_},
#  {_} -> {n},
#  {r} -> {_},
#  {_} -> {r},
#  {u} -> {_},
#  {_} -> {u},
#  {e} -> {a},
#  {a} -> {e},
#  {t} -> {a},
#  {a} -> {t},
#  {e} -> {b},
#  {b} -> {e},
#  {m} -> {b},
#  {b} -> {m},
#  {n} -> {b},
#  {b} -> {n},
#  {r} -> {b},
#  {b} -> {r},
#  {u} -> {b},
#  {b} -> {u},
#  {e} -> {c},
#  {c} -> {e},
#  {i} -> {c},
#  {c} -> {i},
# ...

# %% [markdown]
# Plotting the dataset using stack and bar graph

# %%
items = df.stack()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
items.value_counts().head(10).plot(kind="bar")

plt.xlabel("Top 10 frequent Itemset")
plt.ylabel("Frequecy")
# Out:
# Text(0, 0.5, 'Frequecy')

# %% [markdown]
# Part b : Minimum Support = 60% and Minimum Confidence = 60%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('groceries.csv')

# %%
df1.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
df1.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
df1.shape
# Out:
# (38765, 3)

# %%
df1.describe()
# Out:
#        Member_number
# count   38765.000000
# mean     3003.641868
# std      1153.611031
# min      1000.000000
# 25%      2002.000000
# 50%      3005.000000
# 75%      4007.000000
# max      5000.000000

# %%
# Out:
# array(['tropical fruit', 'whole milk', 'pip fruit', 'other vegetables',
#        'rolls/buns', 'pot plants', 'citrus fruit', 'beef', 'frankfurter',
#        'chicken', 'butter', 'fruit/vegetable juice',
#        'packaged fruit/vegetables', 'chocolate', 'specialty bar',
#        'butter milk', 'bottled water', 'yogurt', 'sausage', 'brown bread',
#        'hamburger meat', 'root vegetables', 'pork', 'pastry',
#        'canned beer', 'berries', 'coffee', 'misc. beverages', 'ham',
#        'turkey', 'curd cheese', 'red/blush wine',
#        'frozen potato products', 'flour', 'sugar', 'frozen meals',
#        'herbs', 'soda', 'detergent', 'grapes', 'processed cheese', 'fish',
#        'sparkling wine', 'newspapers', 'curd', 'pasta', 'popcorn',
#        'finished products', 'beverages', 'bottled beer', 'dessert',
#        'dog food', 'specialty chocolate', 'condensed milk', 'cleaner',
#        'white wine', 'meat', 'ice cream', 'hard cheese', 'cream cheese ',
# ...

# %%
li = []

for i in df1['Member_number'].unique():
    li.append([])

# %%
for i in range(df1.shape[0]):
  li[df1['Member_number'][i]].append(df1['itemDescription'][i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-d19bd414f251> in <cell line: 1>()
#       1 for i in range(df1.shape[0]):
# ----> 2   li[df1['Member_number'][i]].append(df1['itemDescription'][i])
#
# IndexError: list index out of range

# %%
itemset , rules = apriori(df1 , min_support = 0.02 , min_confidence = 0.05)

# %%
itemset
# Out:
# {1: {('M',): 1,
#   ('e',): 3,
#   ('m',): 2,
#   ('b',): 1,
#   ('r',): 2,
#   ('_',): 1,
#   ('n',): 2,
#   ('u',): 1,
#   ('D',): 2,
#   ('a',): 1,
#   ('t',): 2,
#   ('i',): 1,
#   ('s',): 1,
#   ('c',): 1,
#   ('p',): 1,
#   ('o',): 1},
#  2: {('D', 'a'): 1,
#   ('D', 'c'): 1,
#   ('D', 'e'): 2,
#   ('D', 'i'): 1,
#   ('D', 'm'): 1,
#   ('D', 'n'): 1,
#   ('D', 'o'): 1,
#   ('D', 'p'): 1,
#   ('D', 'r'): 1,
#   ('D', 's'): 1,
#   ('D', 't'): 2,
#   ('M', '_'): 1,
#   ('M', 'b'): 1,
#   ('M', 'e'): 1,
#   ('M', 'm'): 1,
#   ('M', 'n'): 1,
#   ('M', 'r'): 1,
#   ('M', 'u'): 1,
#   ('_', 'b'): 1,
#   ('_', 'e'): 1,
#   ('_', 'm'): 1,
#   ('_', 'n'): 1,
#   ('_', 'r'): 1,
#   ('_', 'u'): 1,
#   ('a', 'e'): 1,
#   ('a', 't'): 1,
#   ('b', 'e'): 1,
#   ('b', 'm'): 1,
#   ('b', 'n'): 1,
#   ('b', 'r'): 1,
#   ('b', 'u'): 1,
#   ('c', 'e'): 1,
#   ('c', 'i'): 1,
#   ('c', 'm'): 1,
#   ('c', 'n'): 1,
#   ('c', 'o'): 1,
#   ('c', 'p'): 1,
#   ('c', 'r'): 1,
#   ('c', 's'): 1,
# ...

# %%
rules
# Out:
# [{a} -> {D},
#  {D} -> {a},
#  {c} -> {D},
#  {D} -> {c},
#  {e} -> {D},
#  {D} -> {e},
#  {i} -> {D},
#  {D} -> {i},
#  {m} -> {D},
#  {D} -> {m},
#  {n} -> {D},
#  {D} -> {n},
#  {o} -> {D},
#  {D} -> {o},
#  {p} -> {D},
#  {D} -> {p},
#  {r} -> {D},
#  {D} -> {r},
#  {s} -> {D},
#  {D} -> {s},
#  {t} -> {D},
#  {D} -> {t},
#  {_} -> {M},
#  {M} -> {_},
#  {b} -> {M},
#  {M} -> {b},
#  {e} -> {M},
#  {M} -> {e},
#  {m} -> {M},
#  {M} -> {m},
#  {n} -> {M},
#  {M} -> {n},
#  {r} -> {M},
#  {M} -> {r},
#  {u} -> {M},
#  {M} -> {u},
#  {b} -> {_},
#  {_} -> {b},
#  {e} -> {_},
#  {_} -> {e},
#  {m} -> {_},
#  {_} -> {m},
#  {n} -> {_},
#  {_} -> {n},
#  {r} -> {_},
#  {_} -> {r},
#  {u} -> {_},
#  {_} -> {u},
#  {e} -> {a},
#  {a} -> {e},
#  {t} -> {a},
#  {a} -> {t},
#  {e} -> {b},
#  {b} -> {e},
#  {m} -> {b},
#  {b} -> {m},
#  {n} -> {b},
#  {b} -> {n},
#  {r} -> {b},
#  {b} -> {r},
#  {u} -> {b},
#  {b} -> {u},
#  {e} -> {c},
#  {c} -> {e},
#  {i} -> {c},
#  {c} -> {i},
# ...

# %%
items = df1.stack()
plt.figure()

items.value_counts().head(10).plot(kind="bar")

plt.xlabel("Top 10 frequent Itemset")
plt.ylabel("Frequecy")
# Out:
# Text(0, 0.5, 'Frequecy')
